# %% [markdown]
# <a href="https://colab.research.google.com/github/Ulyphys/machinelearningwithtensor/blob/main/Machine_Learning_with_TensorFlow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense
import tensorflow as tf

def plot_fun(features, labels, classes):
    plt.plot(features[labels[:]==classes[0],0],
             features[labels[:]==classes[0],1], 'rs',
             features[labels[:]==classes[1],0],
             features[labels[:]==classes[1],1], 'g^')
    plt.axis([-2,2,-2,2])
    plt.xlabel('x: feature 1')
    plt.ylabel('y: feature 2')
    plt.legend(['Class' + str(classes[0]), 'Class' + str(classes[1])])
    plt.show()
def plot_fun_thr(features,labels,thre_parms,classes):
  #ploting the data points
  plt.plot(features[labels[:]==classes[0],0], features[labels[:]==classes[0],1], 'rs',
           features[labels[:]==classes[1],0], features[labels[:]==classes[1],1], 'g^', 
           markersize=15)
  #plt.axis([-1,2,-1,2])
  #ploting the seperating line
  x1 = np.linspace(-2,2,50)
  x2 = -(thre_parms[0]*x1+thre_parms[2])/thre_parms[1] 
                      #a X1 + b X2 + c=0 --> x2 = -(a X1 + c)/b
  plt.plot(x1, x2, '-r')
  plt.xlabel('x: feature 1')
  plt.ylabel('y: feature 2')
  plt.legend(['Class'+str(classes[0]), 'Class'+str(classes[1])])
  #plt.pause(0.5)
  #plt.show()

def plot_curve(accuracy_train, loss_train):
  epochs=np.arange(loss_train.shape[0])
  plt.subplot(1,2,1)
  plt.plot(epochs,accuracy_train)
  #plt.axis([-1,2,-1,2])
  plt.xlabel('Epoch#')
  plt.ylabel('Accuracy')
  plt.title('Training Accuracy')

  plt.subplot(1,2,2)
  plt.plot(epochs,loss_train)
  plt.xlabel('Epoch#')
  plt.ylabel('Binary crossentropy loss')
  plt.title('Training loss')

  plt.show()

features = np.array([[0,0],[0,1],[1,0],[1,1]])
labels = np.array([0,1,1,0], dtype=np.uint8)
classes = [0,1]

#plot_fun(features, labels, classes)

#3 Neurons are needed to implement XOR. There are two layers
#With two neurons in the first layer and one in the second.
#We only have two classes two seperate and to seperate these
#Two classes we only need two lines running diagonally. As a result,
#Two lines means only two neurons on the first layer and to differentiate
#The two classes we use on neuron for the output.

#defining the model
model_a=Sequential()
model_a.add(Dense(input_dim=2, units=2, activation='tanh'))
model_a.add(Dense(units=1, activation='sigmoid'))
model_a.summary()

#compiling the model
opt = tf.keras.optimizers.SGD(learning_rate=0.1)
model_a.compile(loss='binary_crossentropy',
              optimizer=opt, 
              metrics=['accuracy'])

features = (features-np.mean(features,axis=0))/np.std(features,axis=0) #normalization
plot_fun(features,labels,classes)

history=model_a.fit(features, labels,
          batch_size=1,
          epochs=200,
          verbose=1)

weights=model_a.layers[0].get_weights() 
plt.figure(figsize=[5,5])

for node_i in range(weights[0].shape[1]):
  thre_parms=np.array(weights[0][:,node_i])#This first item is the weights for the inputs 
  thre_parms=np.append(thre_parms, weights[1][node_i]) #second item the weights for the bias
  plot_fun_thr(features,labels,thre_parms,classes)
plt.show()

acc_curve=np.array(history.history['accuracy'])
loss_curve=np.array(history.history['loss'])
plot_curve(acc_curve,loss_curve)
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_10 (Dense)            (None, 2)                 6
#
#  dense_11 (Dense)            (None, 1)                 3
#
# =================================================================
# Total params: 9
# Trainable params: 9
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.8304 - accuracy: 0.2500
# Epoch 2/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.8006 - accuracy: 0.5000
# Epoch 3/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7744 - accuracy: 0.5000
# Epoch 4/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7491 - accuracy: 0.5000
# Epoch 5/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7252 - accuracy: 0.2500
# Epoch 6/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7042 - accuracy: 0.2500
# Epoch 7/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6842 - accuracy: 0.2500
# Epoch 8/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6669 - accuracy: 0.5000
# Epoch 9/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6507 - accuracy: 0.5000
# Epoch 10/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6353 - accuracy: 0.5000
# Epoch 11/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6196 - accuracy: 0.5000
# Epoch 12/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6039 - accuracy: 0.5000
# Epoch 13/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5890 - accuracy: 0.7500
# Epoch 14/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5738 - accuracy: 0.5000
# Epoch 15/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5594 - accuracy: 0.7500
# Epoch 16/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5447 - accuracy: 1.0000
# Epoch 17/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5301 - accuracy: 1.0000
# Epoch 18/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5160 - accuracy: 1.0000
# Epoch 19/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5019 - accuracy: 1.0000
# Epoch 20/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4883 - accuracy: 0.7500
# Epoch 21/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4749 - accuracy: 1.0000
# Epoch 22/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4618 - accuracy: 1.0000
# Epoch 23/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4491 - accuracy: 1.0000
# Epoch 24/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4367 - accuracy: 1.0000
# Epoch 25/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4247 - accuracy: 1.0000
# Epoch 26/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4129 - accuracy: 1.0000
# Epoch 27/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4015 - accuracy: 1.0000
# Epoch 28/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3903 - accuracy: 1.0000
# Epoch 29/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3797 - accuracy: 1.0000
# Epoch 30/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3692 - accuracy: 1.0000
# Epoch 31/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3594 - accuracy: 1.0000
# Epoch 32/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3498 - accuracy: 1.0000
# Epoch 33/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3403 - accuracy: 1.0000
# Epoch 34/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3314 - accuracy: 1.0000
# Epoch 35/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3227 - accuracy: 1.0000
# Epoch 36/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3144 - accuracy: 1.0000
# Epoch 37/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3063 - accuracy: 1.0000
# Epoch 38/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2987 - accuracy: 1.0000
# Epoch 39/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2911 - accuracy: 1.0000
# Epoch 40/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2840 - accuracy: 1.0000
# Epoch 41/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2770 - accuracy: 1.0000
# Epoch 42/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2703 - accuracy: 1.0000
# Epoch 43/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2639 - accuracy: 1.0000
# Epoch 44/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2577 - accuracy: 1.0000
# Epoch 45/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2517 - accuracy: 1.0000
# Epoch 46/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2459 - accuracy: 1.0000
# Epoch 47/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2404 - accuracy: 1.0000
# Epoch 48/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2350 - accuracy: 1.0000
# Epoch 49/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2299 - accuracy: 1.0000
# Epoch 50/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2249 - accuracy: 1.0000
# Epoch 51/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2201 - accuracy: 1.0000
# Epoch 52/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2155 - accuracy: 1.0000
# Epoch 53/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2110 - accuracy: 1.0000
# Epoch 54/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2066 - accuracy: 1.0000
# Epoch 55/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2025 - accuracy: 1.0000
# Epoch 56/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1985 - accuracy: 1.0000
# Epoch 57/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1945 - accuracy: 1.0000
# Epoch 58/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1908 - accuracy: 1.0000
# Epoch 59/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1871 - accuracy: 1.0000
# Epoch 60/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1836 - accuracy: 1.0000
# Epoch 61/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1802 - accuracy: 1.0000
# Epoch 62/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1769 - accuracy: 1.0000
# Epoch 63/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1737 - accuracy: 1.0000
# Epoch 64/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1705 - accuracy: 1.0000
# Epoch 65/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1676 - accuracy: 1.0000
# Epoch 66/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1646 - accuracy: 1.0000
# Epoch 67/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1618 - accuracy: 1.0000
# Epoch 68/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1591 - accuracy: 1.0000
# Epoch 69/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1564 - accuracy: 1.0000
# Epoch 70/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1538 - accuracy: 1.0000
# Epoch 71/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1513 - accuracy: 1.0000
# Epoch 72/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1489 - accuracy: 1.0000
# Epoch 73/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1465 - accuracy: 1.0000
# Epoch 74/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1442 - accuracy: 1.0000
# Epoch 75/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1420 - accuracy: 1.0000
# Epoch 76/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1398 - accuracy: 1.0000
# Epoch 77/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1377 - accuracy: 1.0000
# Epoch 78/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1356 - accuracy: 1.0000
# Epoch 79/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1336 - accuracy: 1.0000
# Epoch 80/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1316 - accuracy: 1.0000
# Epoch 81/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1297 - accuracy: 1.0000
# Epoch 82/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1279 - accuracy: 1.0000
# Epoch 83/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1261 - accuracy: 1.0000
# Epoch 84/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1243 - accuracy: 1.0000
# Epoch 85/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1226 - accuracy: 1.0000
# Epoch 86/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1210 - accuracy: 1.0000
# Epoch 87/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1193 - accuracy: 1.0000
# Epoch 88/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1177 - accuracy: 1.0000
# Epoch 89/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1162 - accuracy: 1.0000
# Epoch 90/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1147 - accuracy: 1.0000
# Epoch 91/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1132 - accuracy: 1.0000
# Epoch 92/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1117 - accuracy: 1.0000
# Epoch 93/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1103 - accuracy: 1.0000
# Epoch 94/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1090 - accuracy: 1.0000
# Epoch 95/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1076 - accuracy: 1.0000
# Epoch 96/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1063 - accuracy: 1.0000
# Epoch 97/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1050 - accuracy: 1.0000
# Epoch 98/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1038 - accuracy: 1.0000
# Epoch 99/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1025 - accuracy: 1.0000
# Epoch 100/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1013 - accuracy: 1.0000
# Epoch 101/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1001 - accuracy: 1.0000
# Epoch 102/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0990 - accuracy: 1.0000
# Epoch 103/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0979 - accuracy: 1.0000
# Epoch 104/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0968 - accuracy: 1.0000
# Epoch 105/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0957 - accuracy: 1.0000
# Epoch 106/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0946 - accuracy: 1.0000
# Epoch 107/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0936 - accuracy: 1.0000
# Epoch 108/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0926 - accuracy: 1.0000
# Epoch 109/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0916 - accuracy: 1.0000
# Epoch 110/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0906 - accuracy: 1.0000
# Epoch 111/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0896 - accuracy: 1.0000
# Epoch 112/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0887 - accuracy: 1.0000
# Epoch 113/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0878 - accuracy: 1.0000
# Epoch 114/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0869 - accuracy: 1.0000
# Epoch 115/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0860 - accuracy: 1.0000
# Epoch 116/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0851 - accuracy: 1.0000
# Epoch 117/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0843 - accuracy: 1.0000
# Epoch 118/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0834 - accuracy: 1.0000
# Epoch 119/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0826 - accuracy: 1.0000
# Epoch 120/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0818 - accuracy: 1.0000
# Epoch 121/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0810 - accuracy: 1.0000
# Epoch 122/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0803 - accuracy: 1.0000
# Epoch 123/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0795 - accuracy: 1.0000
# Epoch 124/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0788 - accuracy: 1.0000
# Epoch 125/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0780 - accuracy: 1.0000
# Epoch 126/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0773 - accuracy: 1.0000
# Epoch 127/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0766 - accuracy: 1.0000
# Epoch 128/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0759 - accuracy: 1.0000
# Epoch 129/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0752 - accuracy: 1.0000
# Epoch 130/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0745 - accuracy: 1.0000
# Epoch 131/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0739 - accuracy: 1.0000
# Epoch 132/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0732 - accuracy: 1.0000
# Epoch 133/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0726 - accuracy: 1.0000
# Epoch 134/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0719 - accuracy: 1.0000
# Epoch 135/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0713 - accuracy: 1.0000
# Epoch 136/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0707 - accuracy: 1.0000
# Epoch 137/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0701 - accuracy: 1.0000
# Epoch 138/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0695 - accuracy: 1.0000
# Epoch 139/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0690 - accuracy: 1.0000
# Epoch 140/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0684 - accuracy: 1.0000
# Epoch 141/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0678 - accuracy: 1.0000
# Epoch 142/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0673 - accuracy: 1.0000
# Epoch 143/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0667 - accuracy: 1.0000
# Epoch 144/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0662 - accuracy: 1.0000
# Epoch 145/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0657 - accuracy: 1.0000
# Epoch 146/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0651 - accuracy: 1.0000
# Epoch 147/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0646 - accuracy: 1.0000
# Epoch 148/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0641 - accuracy: 1.0000
# Epoch 149/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0636 - accuracy: 1.0000
# Epoch 150/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0631 - accuracy: 1.0000
# Epoch 151/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0626 - accuracy: 1.0000
# Epoch 152/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0622 - accuracy: 1.0000
# Epoch 153/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0617 - accuracy: 1.0000
# Epoch 154/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0612 - accuracy: 1.0000
# Epoch 155/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0608 - accuracy: 1.0000
# Epoch 156/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0603 - accuracy: 1.0000
# Epoch 157/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0599 - accuracy: 1.0000
# Epoch 158/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0595 - accuracy: 1.0000
# Epoch 159/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0590 - accuracy: 1.0000
# Epoch 160/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0586 - accuracy: 1.0000
# Epoch 161/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0582 - accuracy: 1.0000
# Epoch 162/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0578 - accuracy: 1.0000
# Epoch 163/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0574 - accuracy: 1.0000
# Epoch 164/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0570 - accuracy: 1.0000
# Epoch 165/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0566 - accuracy: 1.0000
# Epoch 166/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0562 - accuracy: 1.0000
# Epoch 167/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0558 - accuracy: 1.0000
# Epoch 168/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0554 - accuracy: 1.0000
# Epoch 169/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0550 - accuracy: 1.0000
# Epoch 170/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0547 - accuracy: 1.0000
# Epoch 171/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0543 - accuracy: 1.0000
# Epoch 172/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0539 - accuracy: 1.0000
# Epoch 173/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0536 - accuracy: 1.0000
# Epoch 174/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0532 - accuracy: 1.0000
# Epoch 175/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0529 - accuracy: 1.0000
# Epoch 176/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0525 - accuracy: 1.0000
# Epoch 177/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0522 - accuracy: 1.0000
# Epoch 178/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0519 - accuracy: 1.0000
# Epoch 179/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0515 - accuracy: 1.0000
# Epoch 180/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0512 - accuracy: 1.0000
# Epoch 181/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0509 - accuracy: 1.0000
# Epoch 182/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0506 - accuracy: 1.0000
# Epoch 183/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0502 - accuracy: 1.0000
# Epoch 184/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0499 - accuracy: 1.0000
# Epoch 185/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0496 - accuracy: 1.0000
# Epoch 186/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0493 - accuracy: 1.0000
# Epoch 187/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0490 - accuracy: 1.0000
# Epoch 188/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0487 - accuracy: 1.0000
# Epoch 189/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0484 - accuracy: 1.0000
# Epoch 190/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0481 - accuracy: 1.0000
# Epoch 191/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0478 - accuracy: 1.0000
# Epoch 192/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0476 - accuracy: 1.0000
# Epoch 193/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0473 - accuracy: 1.0000
# Epoch 194/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0470 - accuracy: 1.0000
# Epoch 195/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0467 - accuracy: 1.0000
# Epoch 196/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0465 - accuracy: 1.0000
# Epoch 197/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0462 - accuracy: 1.0000
# Epoch 198/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0459 - accuracy: 1.0000
# Epoch 199/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0457 - accuracy: 1.0000
# Epoch 200/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0454 - accuracy: 1.0000

# %%
#defining the model
model_b=Sequential()
model_b.add(Dense(input_dim=2, units=4, activation='tanh'))
model_b.add(Dense(units=1, activation='sigmoid'))
model_b.summary()

#compiling the model
opt = tf.keras.optimizers.SGD(learning_rate=0.1)
model_b.compile(loss='binary_crossentropy',
              optimizer=opt, 
              metrics=['accuracy'])

features = (features-np.mean(features,axis=0))/np.std(features,axis=0) #normalization
plot_fun(features,labels,classes)

history=model_b.fit(features, labels,
          batch_size=1,
          epochs=400,
          verbose=1)

weights=model_b.layers[0].get_weights() 
plt.figure(figsize=[5,5])

for node_i in range(weights[0].shape[1]):
  thre_parms=np.array(weights[0][:,node_i])#This first item is the weights for the inputs 
  thre_parms=np.append(thre_parms, weights[1][node_i]) #second item the weights for the bias
  plot_fun_thr(features,labels,thre_parms,classes)
plt.show()

acc_curve=np.array(history.history['accuracy'])
loss_curve=np.array(history.history['loss'])
plot_curve(acc_curve,loss_curve)
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_12 (Dense)            (None, 4)                 12
#
#  dense_13 (Dense)            (None, 1)                 5
#
# =================================================================
# Total params: 17
# Trainable params: 17
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7933 - accuracy: 0.5000
# Epoch 2/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7807 - accuracy: 0.2500
# Epoch 3/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7725 - accuracy: 0.2500
# Epoch 4/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7644 - accuracy: 0.5000
# Epoch 5/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7561 - accuracy: 0.0000e+00
# Epoch 6/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7476 - accuracy: 0.0000e+00
# Epoch 7/400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7387 - accuracy: 0.5000
# Epoch 8/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7300 - accuracy: 0.5000
# Epoch 9/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7208 - accuracy: 0.2500
# Epoch 10/400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7120 - accuracy: 0.5000
# Epoch 11/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7021 - accuracy: 0.5000
# Epoch 12/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.6910 - accuracy: 0.5000
# Epoch 13/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.6806 - accuracy: 0.7500
# Epoch 14/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.6710 - accuracy: 0.5000
# Epoch 15/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6587 - accuracy: 0.7500
# Epoch 16/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6471 - accuracy: 1.0000
# Epoch 17/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6362 - accuracy: 0.7500
# Epoch 18/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6236 - accuracy: 0.7500
# Epoch 19/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6117 - accuracy: 0.7500
# Epoch 20/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5988 - accuracy: 0.7500
# Epoch 21/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5857 - accuracy: 1.0000
# Epoch 22/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5722 - accuracy: 1.0000
# Epoch 23/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5589 - accuracy: 0.7500
# Epoch 24/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5445 - accuracy: 0.7500
# Epoch 25/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5308 - accuracy: 0.7500
# Epoch 26/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5162 - accuracy: 1.0000
# Epoch 27/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5021 - accuracy: 1.0000
# Epoch 28/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4873 - accuracy: 0.7500
# Epoch 29/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4726 - accuracy: 1.0000
# Epoch 30/400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4583 - accuracy: 1.0000
# Epoch 31/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4435 - accuracy: 1.0000
# Epoch 32/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4289 - accuracy: 1.0000
# Epoch 33/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4147 - accuracy: 1.0000
# Epoch 34/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4004 - accuracy: 1.0000
# Epoch 35/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3863 - accuracy: 1.0000
# Epoch 36/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3726 - accuracy: 1.0000
# Epoch 37/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3586 - accuracy: 1.0000
# Epoch 38/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3453 - accuracy: 1.0000
# Epoch 39/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3323 - accuracy: 1.0000
# Epoch 40/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3198 - accuracy: 1.0000
# Epoch 41/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3076 - accuracy: 1.0000
# Epoch 42/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2956 - accuracy: 1.0000
# Epoch 43/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2841 - accuracy: 1.0000
# Epoch 44/400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2732 - accuracy: 1.0000
# Epoch 45/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2627 - accuracy: 1.0000
# Epoch 46/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2524 - accuracy: 1.0000
# Epoch 47/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2426 - accuracy: 1.0000
# Epoch 48/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2334 - accuracy: 1.0000
# Epoch 49/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2243 - accuracy: 1.0000
# Epoch 50/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2158 - accuracy: 1.0000
# Epoch 51/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2077 - accuracy: 1.0000
# Epoch 52/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1999 - accuracy: 1.0000
# Epoch 53/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1925 - accuracy: 1.0000
# Epoch 54/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1854 - accuracy: 1.0000
# Epoch 55/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1787 - accuracy: 1.0000
# Epoch 56/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1723 - accuracy: 1.0000
# Epoch 57/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1663 - accuracy: 1.0000
# Epoch 58/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1605 - accuracy: 1.0000
# Epoch 59/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1549 - accuracy: 1.0000
# Epoch 60/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1497 - accuracy: 1.0000
# Epoch 61/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1447 - accuracy: 1.0000
# Epoch 62/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1399 - accuracy: 1.0000
# Epoch 63/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1354 - accuracy: 1.0000
# Epoch 64/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1311 - accuracy: 1.0000
# Epoch 65/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1270 - accuracy: 1.0000
# Epoch 66/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1231 - accuracy: 1.0000
# Epoch 67/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1194 - accuracy: 1.0000
# Epoch 68/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1159 - accuracy: 1.0000
# Epoch 69/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1125 - accuracy: 1.0000
# Epoch 70/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1093 - accuracy: 1.0000
# Epoch 71/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1062 - accuracy: 1.0000
# Epoch 72/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1032 - accuracy: 1.0000
# Epoch 73/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1004 - accuracy: 1.0000
# Epoch 74/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0977 - accuracy: 1.0000
# Epoch 75/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0952 - accuracy: 1.0000
# Epoch 76/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0927 - accuracy: 1.0000
# Epoch 77/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0904 - accuracy: 1.0000
# Epoch 78/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0881 - accuracy: 1.0000
# Epoch 79/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0859 - accuracy: 1.0000
# Epoch 80/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0839 - accuracy: 1.0000
# Epoch 81/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0819 - accuracy: 1.0000
# Epoch 82/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0800 - accuracy: 1.0000
# Epoch 83/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0781 - accuracy: 1.0000
# Epoch 84/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0764 - accuracy: 1.0000
# Epoch 85/400
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0747 - accuracy: 1.0000
# Epoch 86/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0730 - accuracy: 1.0000
# Epoch 87/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0715 - accuracy: 1.0000
# Epoch 88/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0700 - accuracy: 1.0000
# Epoch 89/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0685 - accuracy: 1.0000
# Epoch 90/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0671 - accuracy: 1.0000
# Epoch 91/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0657 - accuracy: 1.0000
# Epoch 92/400
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0644 - accuracy: 1.0000
# Epoch 93/400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0632 - accuracy: 1.0000
# Epoch 94/400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0619 - accuracy: 1.0000
# Epoch 95/400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0608 - accuracy: 1.0000
# Epoch 96/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0596 - accuracy: 1.0000
# Epoch 97/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0585 - accuracy: 1.0000
# Epoch 98/400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0575 - accuracy: 1.0000
# Epoch 99/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0564 - accuracy: 1.0000
# Epoch 100/400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0554 - accuracy: 1.0000
# Epoch 101/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0545 - accuracy: 1.0000
# Epoch 102/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0535 - accuracy: 1.0000
# Epoch 103/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0526 - accuracy: 1.0000
# Epoch 104/400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0517 - accuracy: 1.0000
# Epoch 105/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0509 - accuracy: 1.0000
# Epoch 106/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0500 - accuracy: 1.0000
# Epoch 107/400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0492 - accuracy: 1.0000
# Epoch 108/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0485 - accuracy: 1.0000
# Epoch 109/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0477 - accuracy: 1.0000
# Epoch 110/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0470 - accuracy: 1.0000
# Epoch 111/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0462 - accuracy: 1.0000
# Epoch 112/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0456 - accuracy: 1.0000
# Epoch 113/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0449 - accuracy: 1.0000
# Epoch 114/400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0442 - accuracy: 1.0000
# Epoch 115/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0436 - accuracy: 1.0000
# Epoch 116/400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0429 - accuracy: 1.0000
# Epoch 117/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0423 - accuracy: 1.0000
# Epoch 118/400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0417 - accuracy: 1.0000
# Epoch 119/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0412 - accuracy: 1.0000
# Epoch 120/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0406 - accuracy: 1.0000
# Epoch 121/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0401 - accuracy: 1.0000
# Epoch 122/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0395 - accuracy: 1.0000
# Epoch 123/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0390 - accuracy: 1.0000
# Epoch 124/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0385 - accuracy: 1.0000
# Epoch 125/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0380 - accuracy: 1.0000
# Epoch 126/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0375 - accuracy: 1.0000
# Epoch 127/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0370 - accuracy: 1.0000
# Epoch 128/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0366 - accuracy: 1.0000
# Epoch 129/400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0361 - accuracy: 1.0000
# Epoch 130/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0357 - accuracy: 1.0000
# Epoch 131/400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0352 - accuracy: 1.0000
# Epoch 132/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0348 - accuracy: 1.0000
# Epoch 133/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0344 - accuracy: 1.0000
# Epoch 134/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0340 - accuracy: 1.0000
# Epoch 135/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0336 - accuracy: 1.0000
# Epoch 136/400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0332 - accuracy: 1.0000
# Epoch 137/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0328 - accuracy: 1.0000
# Epoch 138/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0325 - accuracy: 1.0000
# Epoch 139/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0321 - accuracy: 1.0000
# Epoch 140/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0318 - accuracy: 1.0000
# Epoch 141/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0314 - accuracy: 1.0000
# Epoch 142/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0311 - accuracy: 1.0000
# Epoch 143/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0307 - accuracy: 1.0000
# Epoch 144/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0304 - accuracy: 1.0000
# Epoch 145/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0301 - accuracy: 1.0000
# Epoch 146/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0298 - accuracy: 1.0000
# Epoch 147/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0295 - accuracy: 1.0000
# Epoch 148/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0292 - accuracy: 1.0000
# Epoch 149/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0289 - accuracy: 1.0000
# Epoch 150/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0286 - accuracy: 1.0000
# Epoch 151/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0283 - accuracy: 1.0000
# Epoch 152/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0280 - accuracy: 1.0000
# Epoch 153/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0277 - accuracy: 1.0000
# Epoch 154/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0275 - accuracy: 1.0000
# Epoch 155/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0272 - accuracy: 1.0000
# Epoch 156/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0270 - accuracy: 1.0000
# Epoch 157/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0267 - accuracy: 1.0000
# Epoch 158/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0264 - accuracy: 1.0000
# Epoch 159/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0262 - accuracy: 1.0000
# Epoch 160/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0260 - accuracy: 1.0000
# Epoch 161/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0257 - accuracy: 1.0000
# Epoch 162/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0255 - accuracy: 1.0000
# Epoch 163/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0253 - accuracy: 1.0000
# Epoch 164/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0250 - accuracy: 1.0000
# Epoch 165/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0248 - accuracy: 1.0000
# Epoch 166/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0246 - accuracy: 1.0000
# Epoch 167/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0244 - accuracy: 1.0000
# Epoch 168/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0242 - accuracy: 1.0000
# Epoch 169/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0240 - accuracy: 1.0000
# Epoch 170/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0238 - accuracy: 1.0000
# Epoch 171/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0236 - accuracy: 1.0000
# Epoch 172/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0234 - accuracy: 1.0000
# Epoch 173/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0232 - accuracy: 1.0000
# Epoch 174/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0230 - accuracy: 1.0000
# Epoch 175/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0228 - accuracy: 1.0000
# Epoch 176/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0226 - accuracy: 1.0000
# Epoch 177/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0224 - accuracy: 1.0000
# Epoch 178/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0222 - accuracy: 1.0000
# Epoch 179/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0221 - accuracy: 1.0000
# Epoch 180/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0219 - accuracy: 1.0000
# Epoch 181/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0217 - accuracy: 1.0000
# Epoch 182/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0216 - accuracy: 1.0000
# Epoch 183/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0214 - accuracy: 1.0000
# Epoch 184/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0212 - accuracy: 1.0000
# Epoch 185/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0211 - accuracy: 1.0000
# Epoch 186/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0209 - accuracy: 1.0000
# Epoch 187/400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0207 - accuracy: 1.0000
# Epoch 188/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0206 - accuracy: 1.0000
# Epoch 189/400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0204 - accuracy: 1.0000
# Epoch 190/400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0203 - accuracy: 1.0000
# Epoch 191/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0201 - accuracy: 1.0000
# Epoch 192/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0200 - accuracy: 1.0000
# Epoch 193/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0198 - accuracy: 1.0000
# Epoch 194/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0197 - accuracy: 1.0000
# Epoch 195/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0196 - accuracy: 1.0000
# Epoch 196/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0194 - accuracy: 1.0000
# Epoch 197/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0193 - accuracy: 1.0000
# Epoch 198/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0192 - accuracy: 1.0000
# Epoch 199/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0190 - accuracy: 1.0000
# Epoch 200/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0189 - accuracy: 1.0000
# Epoch 201/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0188 - accuracy: 1.0000
# Epoch 202/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0186 - accuracy: 1.0000
# Epoch 203/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0185 - accuracy: 1.0000
# Epoch 204/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0184 - accuracy: 1.0000
# Epoch 205/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0183 - accuracy: 1.0000
# Epoch 206/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0181 - accuracy: 1.0000
# Epoch 207/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0180 - accuracy: 1.0000
# Epoch 208/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0179 - accuracy: 1.0000
# Epoch 209/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0178 - accuracy: 1.0000
# Epoch 210/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0177 - accuracy: 1.0000
# Epoch 211/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0176 - accuracy: 1.0000
# Epoch 212/400
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0174 - accuracy: 1.0000
# Epoch 213/400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0173 - accuracy: 1.0000
# Epoch 214/400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0172 - accuracy: 1.0000
# Epoch 215/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0171 - accuracy: 1.0000
# Epoch 216/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0170 - accuracy: 1.0000
# Epoch 217/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0169 - accuracy: 1.0000
# Epoch 218/400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0168 - accuracy: 1.0000
# Epoch 219/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0167 - accuracy: 1.0000
# Epoch 220/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0166 - accuracy: 1.0000
# Epoch 221/400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0165 - accuracy: 1.0000
# Epoch 222/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0164 - accuracy: 1.0000
# Epoch 223/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0163 - accuracy: 1.0000
# Epoch 224/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0162 - accuracy: 1.0000
# Epoch 225/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0161 - accuracy: 1.0000
# Epoch 226/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0160 - accuracy: 1.0000
# Epoch 227/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0159 - accuracy: 1.0000
# Epoch 228/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0158 - accuracy: 1.0000
# Epoch 229/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0157 - accuracy: 1.0000
# Epoch 230/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0156 - accuracy: 1.0000
# Epoch 231/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0156 - accuracy: 1.0000
# Epoch 232/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0155 - accuracy: 1.0000
# Epoch 233/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0154 - accuracy: 1.0000
# Epoch 234/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0153 - accuracy: 1.0000
# Epoch 235/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0152 - accuracy: 1.0000
# Epoch 236/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0151 - accuracy: 1.0000
# Epoch 237/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0150 - accuracy: 1.0000
# Epoch 238/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0150 - accuracy: 1.0000
# Epoch 239/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0149 - accuracy: 1.0000
# Epoch 240/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0148 - accuracy: 1.0000
# Epoch 241/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0147 - accuracy: 1.0000
# Epoch 242/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0146 - accuracy: 1.0000
# Epoch 243/400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0146 - accuracy: 1.0000
# Epoch 244/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0145 - accuracy: 1.0000
# Epoch 245/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0144 - accuracy: 1.0000
# Epoch 246/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0143 - accuracy: 1.0000
# Epoch 247/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0142 - accuracy: 1.0000
# Epoch 248/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0142 - accuracy: 1.0000
# Epoch 249/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0141 - accuracy: 1.0000
# Epoch 250/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0140 - accuracy: 1.0000
# Epoch 251/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0139 - accuracy: 1.0000
# Epoch 252/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0139 - accuracy: 1.0000
# Epoch 253/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0138 - accuracy: 1.0000
# Epoch 254/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0137 - accuracy: 1.0000
# Epoch 255/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0137 - accuracy: 1.0000
# Epoch 256/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0136 - accuracy: 1.0000
# Epoch 257/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0135 - accuracy: 1.0000
# Epoch 258/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0135 - accuracy: 1.0000
# Epoch 259/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0134 - accuracy: 1.0000
# Epoch 260/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0133 - accuracy: 1.0000
# Epoch 261/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0133 - accuracy: 1.0000
# Epoch 262/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0132 - accuracy: 1.0000
# Epoch 263/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0131 - accuracy: 1.0000
# Epoch 264/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0131 - accuracy: 1.0000
# Epoch 265/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0130 - accuracy: 1.0000
# Epoch 266/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0129 - accuracy: 1.0000
# Epoch 267/400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0129 - accuracy: 1.0000
# Epoch 268/400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0128 - accuracy: 1.0000
# Epoch 269/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0128 - accuracy: 1.0000
# Epoch 270/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0127 - accuracy: 1.0000
# Epoch 271/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0126 - accuracy: 1.0000
# Epoch 272/400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0126 - accuracy: 1.0000
# Epoch 273/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0125 - accuracy: 1.0000
# Epoch 274/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0125 - accuracy: 1.0000
# Epoch 275/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0124 - accuracy: 1.0000
# Epoch 276/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0123 - accuracy: 1.0000
# Epoch 277/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0123 - accuracy: 1.0000
# Epoch 278/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0122 - accuracy: 1.0000
# Epoch 279/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0122 - accuracy: 1.0000
# Epoch 280/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0121 - accuracy: 1.0000
# Epoch 281/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0121 - accuracy: 1.0000
# Epoch 282/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0120 - accuracy: 1.0000
# Epoch 283/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0120 - accuracy: 1.0000
# Epoch 284/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0119 - accuracy: 1.0000
# Epoch 285/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0119 - accuracy: 1.0000
# Epoch 286/400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0118 - accuracy: 1.0000
# Epoch 287/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0118 - accuracy: 1.0000
# Epoch 288/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0117 - accuracy: 1.0000
# Epoch 289/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0116 - accuracy: 1.0000
# Epoch 290/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0116 - accuracy: 1.0000
# Epoch 291/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0115 - accuracy: 1.0000
# Epoch 292/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0115 - accuracy: 1.0000
# Epoch 293/400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0114 - accuracy: 1.0000
# Epoch 294/400
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0114 - accuracy: 1.0000
# Epoch 295/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0114 - accuracy: 1.0000
# Epoch 296/400
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0113 - accuracy: 1.0000
# Epoch 297/400
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0113 - accuracy: 1.0000
# Epoch 298/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0112 - accuracy: 1.0000
# Epoch 299/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0112 - accuracy: 1.0000
# Epoch 300/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0111 - accuracy: 1.0000
# Epoch 301/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0111 - accuracy: 1.0000
# Epoch 302/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0110 - accuracy: 1.0000
# Epoch 303/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0110 - accuracy: 1.0000
# Epoch 304/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0109 - accuracy: 1.0000
# Epoch 305/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0109 - accuracy: 1.0000
# Epoch 306/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0108 - accuracy: 1.0000
# Epoch 307/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0108 - accuracy: 1.0000
# Epoch 308/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0108 - accuracy: 1.0000
# Epoch 309/400
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0107 - accuracy: 1.0000
# Epoch 310/400
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0107 - accuracy: 1.0000
# Epoch 311/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0106 - accuracy: 1.0000
# Epoch 312/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0106 - accuracy: 1.0000
# Epoch 313/400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0105 - accuracy: 1.0000
# Epoch 314/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0105 - accuracy: 1.0000
# Epoch 315/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0105 - accuracy: 1.0000
# Epoch 316/400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0104 - accuracy: 1.0000
# Epoch 317/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0104 - accuracy: 1.0000
# Epoch 318/400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0103 - accuracy: 1.0000
# Epoch 319/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0103 - accuracy: 1.0000
# Epoch 320/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0103 - accuracy: 1.0000
# Epoch 321/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0102 - accuracy: 1.0000
# Epoch 322/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0102 - accuracy: 1.0000
# Epoch 323/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0101 - accuracy: 1.0000
# Epoch 324/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0101 - accuracy: 1.0000
# Epoch 325/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0101 - accuracy: 1.0000
# Epoch 326/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0100 - accuracy: 1.0000
# Epoch 327/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0100 - accuracy: 1.0000
# Epoch 328/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0100 - accuracy: 1.0000
# Epoch 329/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0099 - accuracy: 1.0000
# Epoch 330/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0099 - accuracy: 1.0000
# Epoch 331/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0098 - accuracy: 1.0000
# Epoch 332/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0098 - accuracy: 1.0000
# Epoch 333/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0098 - accuracy: 1.0000
# Epoch 334/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0097 - accuracy: 1.0000
# Epoch 335/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0097 - accuracy: 1.0000
# Epoch 336/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0097 - accuracy: 1.0000
# Epoch 337/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 338/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 339/400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 340/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 341/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 342/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 343/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0094 - accuracy: 1.0000
# Epoch 344/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0094 - accuracy: 1.0000
# Epoch 345/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0094 - accuracy: 1.0000
# Epoch 346/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0093 - accuracy: 1.0000
# Epoch 347/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0093 - accuracy: 1.0000
# Epoch 348/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0093 - accuracy: 1.0000
# Epoch 349/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0092 - accuracy: 1.0000
# Epoch 350/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0092 - accuracy: 1.0000
# Epoch 351/400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0092 - accuracy: 1.0000
# Epoch 352/400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0091 - accuracy: 1.0000
# Epoch 353/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0091 - accuracy: 1.0000
# Epoch 354/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0091 - accuracy: 1.0000
# Epoch 355/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0090 - accuracy: 1.0000
# Epoch 356/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0090 - accuracy: 1.0000
# Epoch 357/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0090 - accuracy: 1.0000
# Epoch 358/400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0089 - accuracy: 1.0000
# Epoch 359/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0089 - accuracy: 1.0000
# Epoch 360/400
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0089 - accuracy: 1.0000
# Epoch 361/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0089 - accuracy: 1.0000
# Epoch 362/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0088 - accuracy: 1.0000
# Epoch 363/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0088 - accuracy: 1.0000
# Epoch 364/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0088 - accuracy: 1.0000
# Epoch 365/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0087 - accuracy: 1.0000
# Epoch 366/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0087 - accuracy: 1.0000
# Epoch 367/400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0087 - accuracy: 1.0000
# Epoch 368/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0087 - accuracy: 1.0000
# Epoch 369/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0086 - accuracy: 1.0000
# Epoch 370/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0086 - accuracy: 1.0000
# Epoch 371/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0086 - accuracy: 1.0000
# Epoch 372/400
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0085 - accuracy: 1.0000
# Epoch 373/400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0085 - accuracy: 1.0000
# Epoch 374/400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0085 - accuracy: 1.0000
# Epoch 375/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0085 - accuracy: 1.0000
# Epoch 376/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0084 - accuracy: 1.0000
# Epoch 377/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0084 - accuracy: 1.0000
# Epoch 378/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0084 - accuracy: 1.0000
# Epoch 379/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0084 - accuracy: 1.0000
# Epoch 380/400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0083 - accuracy: 1.0000
# Epoch 381/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0083 - accuracy: 1.0000
# Epoch 382/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0083 - accuracy: 1.0000
# Epoch 383/400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0082 - accuracy: 1.0000
# Epoch 384/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0082 - accuracy: 1.0000
# Epoch 385/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0082 - accuracy: 1.0000
# Epoch 386/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0082 - accuracy: 1.0000
# Epoch 387/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0081 - accuracy: 1.0000
# Epoch 388/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0081 - accuracy: 1.0000
# Epoch 389/400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0081 - accuracy: 1.0000
# Epoch 390/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0081 - accuracy: 1.0000
# Epoch 391/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0080 - accuracy: 1.0000
# Epoch 392/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0080 - accuracy: 1.0000
# Epoch 393/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0080 - accuracy: 1.0000
# Epoch 394/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0080 - accuracy: 1.0000
# Epoch 395/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0079 - accuracy: 1.0000
# Epoch 396/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0079 - accuracy: 1.0000
# Epoch 397/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0079 - accuracy: 1.0000
# Epoch 398/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0079 - accuracy: 1.0000
# Epoch 399/400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0079 - accuracy: 1.0000
# Epoch 400/400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0078 - accuracy: 1.0000

# %%
from keras.datasets import mnist
import matplotlib.pyplot as plt
import numpy as np
from random import randint

def img_plt(images, labels):
  plt.figure()
  for i in range(1,11):
    plt.subplot(2,5,i)
    plt.imshow(images[i-1,:,:],cmap='gray')
    plt.title('Label: ' + str(labels[i-1]))
  plt.show()

def feat_extract(images):
  width=images.shape[1]
  height=images.shape[2]
  features=np.zeros((images.shape[0],4))
  features_temp=np.sum(images[:,0:int(width/2),0:int(height/2)],axis=2)#quadrant 0
  features[:,0]=np.sum(features_temp,axis=1)/(width*height/4)
  features_temp=np.sum(images[:,0:int(width/2),int(height/2):],axis=2) #quadrant 1
  features[:,1]=np.sum(features_temp,axis=1)/(width*height/4)
  features_temp=np.sum(images[:,int(width/2):,0:int(height/2)],axis=2) #quadrant 2
  features[:,2]=np.sum(features_temp,axis=1)/(width*height/4)
  features_temp=np.sum(images[:,int(width/2):,int(height/2):],axis=2)  #quadrant 3
  features[:,3]=np.sum(features_temp,axis=1)/(width*height/4)
  return features

def feat_plot(features,labels,classes):
  for class_i in classes:
    plt.plot(features[labels[:]==classes[class_i],0], 
             features[labels[:]==classes[class_i],1],'o', markersize=15)
  #plt.axis([-2,2,-2,2])
  plt.xlabel('x: feature 1')
  plt.ylabel('y: feature 2')
  plt.legend(['Class'+str(classes[class_i]) for class_i in classes])
  plt.show()

def acc_fun(labels_actual, labels_pred):
  acc=np.sum(labels_actual==labels_pred)/len(labels_actual)*100
  return acc

(x_train, y_train), (x_test, y_test) = mnist.load_data()

#Selecting only 0 and 1 and 2 digits from the training and testing sets
classes=[0,1,2]
x_train_012=x_train[np.logical_or.reduce((y_train==0,y_train==1,y_train==2)),0:28,0:28]
y_train_012=y_train[np.logical_or.reduce((y_train==0,y_train==1,y_train==2))]
print('Samples of the training images')
img_plt(x_train_012[0:10,:,:],y_train_012[0:10])

x_test_012=x_test[np.logical_or.reduce((y_test==0,y_test==1,y_test==2)),0:28,0:28]
y_test_012=y_test[np.logical_or.reduce((y_test==0,y_test==1,y_test==2))]
print('Samples of the testing images')
img_plt(x_test_012[0:10,:,:],y_test_012[0:10])

#Selecting 500 images from training data as the validation set
#shuffling trainig data
num_train_img=x_train_012.shape[0]
train_ind=np.arange(0,num_train_img)
train_ind_s=np.random.permutation(train_ind)
x_train_012=x_train_012[train_ind_s,:,:]
y_train_012=y_train_012[train_ind_s]
#Selecting 500 images for validation
x_val_012=x_train_012[0:500,:,:]
y_val_012=y_train_012[0:500]
#The rest of the training set
x_train_012=x_train_012[500:,:,:]
y_train_012=y_train_012[500:]
print('Samples of the validation images')
img_plt(x_val_012[0:10,:,:],y_val_012[0:10])

#Calculating the training, validation and testing feature (average of the four quadrants grid)
feature_train=feat_extract(x_train_012)
feature_val=feat_extract(x_val_012)
feature_test=feat_extract(x_test_012)

print('Plotting the features of 500 training images: ')
feat_plot(feature_train[1:500, 0:2],y_train_012[1:500], classes)
feat_plot(feature_train[1:500, 2:4],y_train_012[1:500], classes) 
#The combination between the features could be changed
# Out:
# Samples of the training images
# Samples of the testing images
# 18623
# Samples of the validation images
# Plotting the features of 500 training images:

# %%
from keras.models import Sequential
from keras.layers import Dense
import tensorflow as tf

def plot_curve(accuracy_train, loss_train):
  epochs=np.arange(loss_train.shape[0])
  plt.subplot(1,2,1)
  plt.plot(epochs,accuracy_train)
  #plt.axis([-1,2,-1,2])
  plt.xlabel('Epoch#')
  plt.ylabel('Accuracy')
  plt.title('Training Accuracy')

  plt.subplot(1,2,2)
  plt.plot(epochs,loss_train)
  plt.xlabel('Epoch#')
  plt.ylabel('Binary crossentropy loss')
  plt.title('Training loss')
  plt.show()

#defining the model
model_a=Sequential()
model_a.add(Dense(input_dim=4, units=100, activation='tanh'))
model_a.add(Dense(units=50, activation='tanh'))
model_a.add(Dense(units=len(classes), activation='softmax'))
model_a.summary()

opt = tf.keras.optimizers.SGD(learning_rate=0.0001)
model_a.compile(loss='categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])

# convert class vectors to binary class matrices
from keras.utils.np_utils import to_categorical
y_train_012_c = to_categorical(y_train_012, len(classes))
y_val_012_c = to_categorical(y_val_012, len(classes))
y_test_012_c = to_categorical(y_test_012, len(classes))

history=model_a.fit(feature_train, y_train_012_c,
          batch_size=16,
          epochs=50,
          verbose=1)

#Evaluating the model on the training samples
score=model_a.evaluate(feature_train,y_train_012_c)
print('Total loss on training set: ', score[0])
print('Accuracy of training set: ', score[1])

#Evaluating the model on the validation samples
score=model_a.evaluate(feature_val,y_val_012_c)
print('Total loss on validation set: ', score[0])
print('Accuracy of validation set: ', score[1])

plt.figure(figsize=[9,5])
acc_curve=np.array(history.history['accuracy'])
loss_curve=np.array(history.history['loss'])
plot_curve(acc_curve,loss_curve)
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_25 (Dense)            (None, 100)               500
#
#  dense_26 (Dense)            (None, 50)                5050
#
#  dense_27 (Dense)            (None, 3)                 153
#
# =================================================================
# Total params: 5,703
# Trainable params: 5,703
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 1133/1133 [==============================] - 5s 4ms/step - loss: 0.8533 - accuracy: 0.6772
# Epoch 2/50
# 1133/1133 [==============================] - 4s 3ms/step - loss: 0.6029 - accuracy: 0.8314
# Epoch 3/50
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.5109 - accuracy: 0.8660
# Epoch 4/50
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.4616 - accuracy: 0.8739
# Epoch 5/50
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.4300 - accuracy: 0.8765
# Epoch 6/50
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.4080 - accuracy: 0.8784
# Epoch 7/50
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.3916 - accuracy: 0.8793
# Epoch 8/50
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.3793 - accuracy: 0.8797
# Epoch 9/50
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.3694 - accuracy: 0.8803
# Epoch 10/50
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.3616 - accuracy: 0.8816
# Epoch 11/50
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.3550 - accuracy: 0.8824
# Epoch 12/50
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.3498 - accuracy: 0.8827
# Epoch 13/50
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.3450 - accuracy: 0.8829
# Epoch 14/50
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.3410 - accuracy: 0.8837
# Epoch 15/50
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.3373 - accuracy: 0.8835
# Epoch 16/50
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.3340 - accuracy: 0.8838
# Epoch 17/50
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.3312 - accuracy: 0.8846
# Epoch 18/50
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.3287 - accuracy: 0.8850
# Epoch 19/50
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.3269 - accuracy: 0.8856
# Epoch 20/50
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.3248 - accuracy: 0.8858
# Epoch 21/50
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.3230 - accuracy: 0.8855
# Epoch 22/50
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.3211 - accuracy: 0.8863
# Epoch 23/50
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.3198 - accuracy: 0.8867
# Epoch 24/50
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.3184 - accuracy: 0.8868
# Epoch 25/50
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.3168 - accuracy: 0.8869
# Epoch 26/50
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.3156 - accuracy: 0.8869
# Epoch 27/50
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.3146 - accuracy: 0.8870
# Epoch 28/50
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.3134 - accuracy: 0.8878
# Epoch 29/50
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.3123 - accuracy: 0.8869
# Epoch 30/50
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.3113 - accuracy: 0.8873
# Epoch 31/50
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.3105 - accuracy: 0.8884
# Epoch 32/50
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.3094 - accuracy: 0.8883
# Epoch 33/50
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.3087 - accuracy: 0.8889
# Epoch 34/50
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.3077 - accuracy: 0.8877
# Epoch 35/50
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.3070 - accuracy: 0.8881
# Epoch 36/50
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.3062 - accuracy: 0.8885
# Epoch 37/50
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.3054 - accuracy: 0.8895
# Epoch 38/50
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.3048 - accuracy: 0.8891
# Epoch 39/50
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.3041 - accuracy: 0.8892
# Epoch 40/50
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.3034 - accuracy: 0.8892
# Epoch 41/50
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.3027 - accuracy: 0.8901
# Epoch 42/50
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.3021 - accuracy: 0.8895
# Epoch 43/50
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.3016 - accuracy: 0.8895
# Epoch 44/50
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.3008 - accuracy: 0.8893
# Epoch 45/50
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.3004 - accuracy: 0.8897
# Epoch 46/50
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.2998 - accuracy: 0.8894
# Epoch 47/50
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.2994 - accuracy: 0.8898
# Epoch 48/50
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.2986 - accuracy: 0.8902
# Epoch 49/50
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.2981 - accuracy: 0.8904
# Epoch 50/50
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.2976 - accuracy: 0.8907
# 567/567 [==============================] - 1s 1ms/step - loss: 0.2968 - accuracy: 0.8909
# Total loss on training set:  0.2967612147331238
# Accuracy of training set:  0.8909121155738831
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2689 - accuracy: 0.9060
# Total loss on validation set:  0.26891741156578064
# Accuracy of validation set:  0.906000018119812

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, recall_score
#Evaluating the model on the held-out samples
score=model_a.evaluate(feature_test,y_test_012_c)
print('Total loss on testing set: ', score[0])
print('Accuracy of testing set: ', score[1])

from sklearn.metrics import accuracy_score, confusion_matrix, recall_score
#predicting the class of the held-out samples
test_class1_prob=model_a.predict(feature_test)
test_lab=np.argmax(test_class1_prob,axis=1)
print('The accuracy using the testing set: ', 
      accuracy_score(test_lab,y_test_012))
conf_mat=confusion_matrix(test_lab,y_test_012)
print('The confusion matrix using testing set: \n', 
      conf_mat)
# Out:
# 99/99 [==============================] - 0s 2ms/step - loss: 0.3176 - accuracy: 0.8796
# Total loss on testing set:  0.3175775706768036
# Accuracy of testing set:  0.8795678615570068
# The accuracy using the testing set:  0.8795678423895774
# The confusion matrix using testing set:
#  [[ 910   38  188]
#  [   7 1060   46]
#  [  63   37  798]]

# %%
import pandas as pd
from google.colab import drive
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
import tensorflow as tf
import matplotlib.pyplot as plt

def img_plt(images, labels):
  plt.figure()
  for i in range(1,11):
    plt.subplot(2,5,i)
    plt.imshow(images[i-1,:,:],cmap='gray')
    plt.title('Label: ' + str(labels[i-1]))
  plt.show()

def feat_extract(images):
  width=images.shape[1]
  height=images.shape[2]
  features=np.zeros((images.shape[0],4))
  features_temp=np.sum(images[:,0:int(width/2),0:int(height/2)],axis=2)#quadrant 0
  features[:,0]=np.sum(features_temp,axis=1)/(width*height/4)
  features_temp=np.sum(images[:,0:int(width/2),int(height/2):],axis=2) #quadrant 1
  features[:,1]=np.sum(features_temp,axis=1)/(width*height/4)
  features_temp=np.sum(images[:,int(width/2):,0:int(height/2)],axis=2) #quadrant 2
  features[:,2]=np.sum(features_temp,axis=1)/(width*height/4)
  features_temp=np.sum(images[:,int(width/2):,int(height/2):],axis=2)  #quadrant 3
  features[:,3]=np.sum(features_temp,axis=1)/(width*height/4)
  return features

def feat_plot(features,labels,classes):
  for class_i in classes:
    plt.plot(features[labels[:]==classes[class_i],0], 
             features[labels[:]==classes[class_i],1],'o', markersize=15)
  #plt.axis([-2,2,-2,2])
  plt.xlabel('x: feature 1')
  plt.ylabel('y: feature 2')
  plt.legend(['Class'+str(classes[class_i]) for class_i in classes])
  plt.show()

def acc_fun(labels_actual, labels_pred):
  acc=np.sum(labels_actual==labels_pred)/len(labels_actual)*100
  return acc

def plot_curve(accuracy_train, loss_train):
  epochs=np.arange(loss_train.shape[0])
  plt.subplot(1,2,1)
  plt.plot(epochs,accuracy_train)
  #plt.axis([-1,2,-1,2])
  plt.xlabel('Epoch#')
  plt.ylabel('Accuracy')
  plt.title('Training Accuracy')

  plt.subplot(1,2,2)
  plt.plot(epochs,loss_train)
  plt.xlabel('Epoch#')
  plt.ylabel('Binary crossentropy loss')
  plt.title('Training loss')

  plt.show()

drive.mount('/drive')
spotify_data = pd.read_csv('/drive/MyDrive/Colab Notebooks/spotify_preprocessed.csv')
spotify_data = np.array(spotify_data)
#print(spotify_data)

classes = [0,1]

train_ind_s=np.random.permutation(spotify_data)
num_train_items=train_ind_s.shape[0]
print(num_train_items)

x_train = train_ind_s[:, :-1]
y_train = train_ind_s[:, -1]

#print(x_train)
#print(y_train)

x_test=x_train[0:int(0.1*num_train_items),:]
y_test=y_train[0:int(0.1*num_train_items)]

print(x_test.shape[0])

x_train=x_train[int(0.1*num_train_items):,:]
y_train=y_train[int(0.1*num_train_items):]

print(x_train.shape[0])

x_val=x_train[0:int(.2*x_train.shape[0]),:]
y_val=y_train[0:int(.2*x_train.shape[0])]

x_train=x_train[int(0.2*num_train_items):,:]
y_train=y_train[int(0.2*num_train_items):]

print(x_train.shape[0])
print(x_val.shape[0])
#print(x_train)
#print(y_train)
#defining the model

#feature_train=feat_extract(x_train)
#feature_val=feat_extract(x_val)
#feature_test=feat_extract(x_test)

model_a=Sequential()
model_a.add(Dense(input_dim=15, units=64, activation='tanh'))
model_a.add(Dense(units=64, activation='tanh'))
model_a.add(Dense(units=64, activation='tanh'))
model_a.add(Dense(units=len(classes), activation='softmax'))
model_a.summary()

opt = tf.keras.optimizers.SGD(learning_rate=0.05)
model_a.compile(loss='binary_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])

# convert class vectors to binary class matrices
from keras.utils.np_utils import to_categorical
y_train = to_categorical(y_train, len(classes))
y_val = to_categorical(y_val, len(classes))
y_test = to_categorical(y_test, len(classes))

history=model_a.fit(x_train, y_train,
          batch_size=16,
          epochs=50,
          verbose=1)

#Evaluating the model on the training samples
score=model_a.evaluate(x_train,y_train)
print('Total loss on training set: ', score[0])
print('Accuracy of training set: ', score[1])

#Evaluating the model on the validation samples
score=model_a.evaluate(x_val,y_val)
print('Total loss on validation set: ', score[0])
print('Accuracy of validation set: ', score[1])

plt.figure(figsize=[9,5])
acc_curve=np.array(history.history['accuracy'])
loss_curve=np.array(history.history['loss'])
plot_curve(acc_curve,loss_curve)

from sklearn.metrics import accuracy_score, confusion_matrix, recall_score
#Evaluating the model on the held-out samples
score=model_a.evaluate(x_test,y_test)
print('Total loss on testing set: ', score[0])
print('Accuracy of testing set: ', score[1])
# Out:
# Drive already mounted at /drive; to attempt to forcibly remount, call drive.mount("/drive", force_remount=True).
# 6398
# 639
# 5759
# 4480
# 1151
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_32 (Dense)            (None, 64)                1024
#
#  dense_33 (Dense)            (None, 64)                4160
#
#  dense_34 (Dense)            (None, 64)                4160
#
#  dense_35 (Dense)            (None, 2)                 130
#
# =================================================================
# Total params: 9,474
# Trainable params: 9,474
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 280/280 [==============================] - 1s 2ms/step - loss: 0.5485 - accuracy: 0.7248
# Epoch 2/50
# 280/280 [==============================] - 0s 1ms/step - loss: 0.4885 - accuracy: 0.7576
# Epoch 3/50
# 280/280 [==============================] - 0s 1ms/step - loss: 0.4807 - accuracy: 0.7638
# Epoch 4/50
# 280/280 [==============================] - 0s 1ms/step - loss: 0.4793 - accuracy: 0.7645
# Epoch 5/50
# 280/280 [==============================] - 0s 1ms/step - loss: 0.4687 - accuracy: 0.7708
# Epoch 6/50
# 280/280 [==============================] - 0s 1ms/step - loss: 0.4701 - accuracy: 0.7681
# Epoch 7/50
# 280/280 [==============================] - 0s 1ms/step - loss: 0.4644 - accuracy: 0.7779
# Epoch 8/50
# 280/280 [==============================] - 0s 1ms/step - loss: 0.4599 - accuracy: 0.7763
# Epoch 9/50
# 280/280 [==============================] - 0s 1ms/step - loss: 0.4578 - accuracy: 0.7721
# Epoch 10/50
# 280/280 [==============================] - 0s 1ms/step - loss: 0.4496 - accuracy: 0.7842
# Epoch 11/50
# 280/280 [==============================] - 0s 1ms/step - loss: 0.4458 - accuracy: 0.7886
# Epoch 12/50
# 280/280 [==============================] - 0s 1ms/step - loss: 0.4410 - accuracy: 0.7953
# Epoch 13/50
# 280/280 [==============================] - 0s 1ms/step - loss: 0.4357 - accuracy: 0.7929
# Epoch 14/50
# 280/280 [==============================] - 0s 1ms/step - loss: 0.4277 - accuracy: 0.8007
# Epoch 15/50
# 280/280 [==============================] - 0s 1ms/step - loss: 0.4272 - accuracy: 0.8002
# Epoch 16/50
# 280/280 [==============================] - 0s 2ms/step - loss: 0.4252 - accuracy: 0.8045
# Epoch 17/50
# 280/280 [==============================] - 0s 1ms/step - loss: 0.4222 - accuracy: 0.8069
# Epoch 18/50
# 280/280 [==============================] - 0s 1ms/step - loss: 0.4188 - accuracy: 0.8051
# Epoch 19/50
# 280/280 [==============================] - 0s 1ms/step - loss: 0.4160 - accuracy: 0.8058
# Epoch 20/50
# 280/280 [==============================] - 0s 1ms/step - loss: 0.4183 - accuracy: 0.8040
# Epoch 21/50
# 280/280 [==============================] - 0s 1ms/step - loss: 0.4163 - accuracy: 0.8087
# Epoch 22/50
# 280/280 [==============================] - 0s 1ms/step - loss: 0.4155 - accuracy: 0.8033
# Epoch 23/50
# 280/280 [==============================] - 0s 2ms/step - loss: 0.4152 - accuracy: 0.8062
# Epoch 24/50
# 280/280 [==============================] - 0s 1ms/step - loss: 0.4153 - accuracy: 0.8056
# Epoch 25/50
# 280/280 [==============================] - 0s 2ms/step - loss: 0.4136 - accuracy: 0.8121
# Epoch 26/50
# 280/280 [==============================] - 0s 1ms/step - loss: 0.4153 - accuracy: 0.8092
# Epoch 27/50
# 280/280 [==============================] - 0s 1ms/step - loss: 0.4156 - accuracy: 0.8031
# Epoch 28/50
# 280/280 [==============================] - 0s 1ms/step - loss: 0.4114 - accuracy: 0.8127
# Epoch 29/50
# 280/280 [==============================] - 0s 1ms/step - loss: 0.4109 - accuracy: 0.8129
# Epoch 30/50
# 280/280 [==============================] - 0s 1ms/step - loss: 0.4130 - accuracy: 0.8098
# Epoch 31/50
# 280/280 [==============================] - 0s 1ms/step - loss: 0.4118 - accuracy: 0.8062
# Epoch 32/50
# 280/280 [==============================] - 0s 1ms/step - loss: 0.4086 - accuracy: 0.8127
# Epoch 33/50
# 280/280 [==============================] - 0s 1ms/step - loss: 0.4085 - accuracy: 0.8138
# Epoch 34/50
# 280/280 [==============================] - 0s 1ms/step - loss: 0.4075 - accuracy: 0.8107
# Epoch 35/50
# 280/280 [==============================] - 0s 1ms/step - loss: 0.4086 - accuracy: 0.8174
# Epoch 36/50
# 280/280 [==============================] - 0s 1ms/step - loss: 0.4090 - accuracy: 0.8205
# Epoch 37/50
# 280/280 [==============================] - 0s 2ms/step - loss: 0.4097 - accuracy: 0.8080
# Epoch 38/50
# 280/280 [==============================] - 0s 1ms/step - loss: 0.4078 - accuracy: 0.8134
# Epoch 39/50
# 280/280 [==============================] - 0s 1ms/step - loss: 0.4053 - accuracy: 0.8205
# Epoch 40/50
# 280/280 [==============================] - 0s 1ms/step - loss: 0.4025 - accuracy: 0.8210
# Epoch 41/50
# 280/280 [==============================] - 0s 1ms/step - loss: 0.4067 - accuracy: 0.8143
# Epoch 42/50
# 280/280 [==============================] - 0s 2ms/step - loss: 0.4060 - accuracy: 0.8163
# Epoch 43/50
# 280/280 [==============================] - 0s 1ms/step - loss: 0.4049 - accuracy: 0.8138
# Epoch 44/50
# 280/280 [==============================] - 0s 1ms/step - loss: 0.4064 - accuracy: 0.8188
# Epoch 45/50
# 280/280 [==============================] - 0s 1ms/step - loss: 0.4047 - accuracy: 0.8138
# Epoch 46/50
# 280/280 [==============================] - 0s 1ms/step - loss: 0.4056 - accuracy: 0.8141
# Epoch 47/50
# 280/280 [==============================] - 0s 1ms/step - loss: 0.4051 - accuracy: 0.8127
# Epoch 48/50
# 280/280 [==============================] - 0s 1ms/step - loss: 0.4049 - accuracy: 0.8143
# Epoch 49/50
# 280/280 [==============================] - 0s 1ms/step - loss: 0.4043 - accuracy: 0.8170
# Epoch 50/50
# 280/280 [==============================] - 0s 1ms/step - loss: 0.4042 - accuracy: 0.8161
# 140/140 [==============================] - 0s 1ms/step - loss: 0.4034 - accuracy: 0.8174
# Total loss on training set:  0.40341901779174805
# Accuracy of training set:  0.8174107074737549
# 36/36 [==============================] - 0s 2ms/step - loss: 0.4239 - accuracy: 0.8089
# Total loss on validation set:  0.4238553047180176
# Accuracy of validation set:  0.8088618516921997
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3923 - accuracy: 0.8326
# Total loss on testing set:  0.39226219058036804
# Accuracy of testing set:  0.8325508832931519

# %%
# !wget -nc https://raw.githubusercontent.com/brpy/colab-pdf/master/colab_pdf.py
from colab_pdf import colab_pdf
colab_pdf('Assignment_5.ipynb')
# Out:
# File ‘colab_pdf.py’ already there; not retrieving.
#
#
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
#
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
# [NbConvertApp] Converting notebook /content/drive/MyDrive/Colab Notebooks/Assignment_5.ipynb to pdf
# [NbConvertApp] Support files will be in Assignment_5_files/
# [NbConvertApp] Making directory ./Assignment_5_files
# [NbConvertApp] Making directory ./Assignment_5_files
# [NbConvertApp] Making directory ./Assignment_5_files
# [NbConvertApp] Making directory ./Assignment_5_files
# [NbConvertApp] Making directory ./Assignment_5_files
# [NbConvertApp] Making directory ./Assignment_5_files
# [NbConvertApp] Making directory ./Assignment_5_files
# [NbConvertApp] Making directory ./Assignment_5_files
# [NbConvertApp] Making directory ./Assignment_5_files
# [NbConvertApp] Making directory ./Assignment_5_files
# [NbConvertApp] Making directory ./Assignment_5_files
# [NbConvertApp] Making directory ./Assignment_5_files
# [NbConvertApp] Making directory ./Assignment_5_files
# [NbConvertApp] Writing 152651 bytes to ./notebook.tex
# [NbConvertApp] Building PDF
# [NbConvertApp] Running xelatex 3 times: ['xelatex', './notebook.tex', '-quiet']
# [NbConvertApp] Running bibtex 1 time: ['bibtex', './notebook']
# [NbConvertApp] WARNING | bibtex had problems, most likely because there were no citations
# [NbConvertApp] PDF successfully created
# [NbConvertApp] Writing 289484 bytes to /content/drive/My Drive/Assignment_5.pdf
# 'File ready to be Downloaded and Saved to Drive'
